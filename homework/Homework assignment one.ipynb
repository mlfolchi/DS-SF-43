# %% [markdown]
# # Homework Assignment Number One

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Section 1: Police killings

# %%
killings = pd.read_csv('../data/police-killings.csv', index_col=[0], encoding='latin-1')
killings.head()
# Out:
#                  name  age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# ...

# %% [markdown]
# ### 1. Make the following changes to column names:
#
# - lawenforcementagency -> agency
# - raceethnicity -> race

# %%
killings.rename(columns={"lawenforcementagency":"agency", "raceethnicity":"race"}, inplace=True)
killings.head()
# Out:
#                  name  age gender             race     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#                             agency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
killings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 467 entries, 0 to 466
# Data columns (total 14 columns):
# name             467 non-null object
# age              467 non-null int64
# gender           467 non-null object
# race             467 non-null object
# month            467 non-null object
# day              467 non-null int64
# year             467 non-null int64
# streetaddress    463 non-null object
# city             467 non-null object
# state            467 non-null object
# agency           467 non-null object
# cause            467 non-null object
# armed            467 non-null object
# county_income    467 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 54.7+ KB

# %%
killings.isnull().sum()
# Out:
# name             0
# age              0
# gender           0
# race             0
# month            0
# day              0
# year             0
# streetaddress    4
# city             0
# state            0
# agency           0
# cause            0
# armed            0
# county_income    0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
killings.age.hist(by = killings.gender, bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7aaef0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e8f1940>], dtype=object)

# %% [markdown]
# ### 3. Replace each null value in the dataframe with the string "unknown"

# %%
killings.streetaddress.fillna("unknown", inplace=True)
killings.isnull().sum()
# Out:
# name             0
# age              0
# gender           0
# race             0
# month            0
# day              0
# year             0
# streetaddress    0
# city             0
# state            0
# agency           0
# cause            0
# armed            0
# county_income    0
# dtype: int64

# %% [markdown]
# ### 4. How many killings were there in March and April?

# %%
spring = ["March", "April"]
killings[killings.month.isin(spring)]
# Out:
#                       name  age  gender                    race  month  day  \
# 1           Aaron Rutledge   27    Male                   White  April    2
# 2              Aaron Siler   26    Male                   White  March   14
# 3             Aaron Valdez   25    Male         Hispanic/Latino  March   11
# 4             Adam Jovicic   29    Male                   White  March   19
# 5            Adam Reinhart   29    Male                   White  March    7
# 6         Adrian Hernandez   22    Male         Hispanic/Latino  March   27
# 7             Adrian Solis   35    Male         Hispanic/Latino  March   26
# 10        Albert Hanson Jr   76    Male                   White  April   26
# 14         Alexander Myers   23    Male                   White  April    6
# 16        Alexia Christian   25  Female                   Black  April   30
# 18             Alice Brown   24  Female                   White  March   17
# ...

# %%
killings["spring"] = killings.month.isin(spring)
killings.spring.value_counts()
# Out:
# False    257
# True     210
# Name: spring, dtype: int64

# %% [markdown]
# ### 5. How many male and how many female victims are there?

# %%
killings.shape
# Out:
# (467, 15)

# %%
killings.gender.value_counts()
# Out:
# Male      445
# Female     22
# Name: gender, dtype: int64

# %%
#killings.plot()

# %%
killings.gender.value_counts().plot(kind="pie", 
                                    title="Police Killings by Gender",
                                   colormap="Spectral")

# %% [markdown]
# ### 6. How many killings were of unarmed people?

# %%
killings.armed.value_counts()
# Out:
# Firearm               230
# No                    102
# Knife                  68
# Other                  26
# Vehicle                18
# Non-lethal firearm     14
# Unknown                 7
# Disputed                2
# Name: armed, dtype: int64

# %%
killings.armed.value_counts().plot(kind="barh", color="cyan")

# %% [markdown]
# ### 7. What percentage of all killings were unarmed?

# %%
killings.armed.value_counts(normalize=True) * 100
# Out:
# Firearm               49.250535
# No                    21.841542
# Knife                 14.561028
# Other                  5.567452
# Vehicle                3.854390
# Non-lethal firearm     2.997859
# Unknown                1.498929
# Disputed               0.428266
# Name: armed, dtype: float64

# %%
#this shows all instances of unarmed killings
unarmed = ["No"]
killings[killings.armed.isin(unarmed)]
# Out:
#                            name  age  gender                    race  \
# 0            A'donte Washington   16    Male                   Black
# 1                Aaron Rutledge   27    Male                   White
# 2                   Aaron Siler   26    Male                   White
# 4                  Adam Jovicic   29    Male                   White
# 5                 Adam Reinhart   29    Male                   White
# 11               Alec Ouzounian   40    Male                   White
# 12            Alejandro Salazar   40    Male         Hispanic/Latino
# 19                 Alvin Haynes   57    Male                   Black
# 21              Andre Murphy Sr   42    Male                   Black
# 36                 Anthony Hill   27    Male                   Black
# 47                Bernard Moore   62    Male                   Black
# 63                Bruce Zalonka   46    Male  Asian/Pacific Islander
# 70                 Caso Jackson   25    Male                   Black
# ...

# %% [markdown]
# ### 8. What are the 5 states with the most killings?

# %%
killings.state.value_counts(sort=True, ascending=False).head()
# Out:
# CA    74
# TX    46
# FL    29
# AZ    25
# OK    22
# Name: state, dtype: int64

# %%
plt.figure(figsize=(20,12))
killings.state.value_counts(sort=True, ascending=False).plot(kind="barh")

# %% [markdown]
# ### 9. Show a value counts of deaths for each race

# %%
killings.race.value_counts()
# Out:
# White                     236
# Black                     135
# Hispanic/Latino            67
# Unknown                    15
# Asian/Pacific Islander     10
# Native American             4
# Name: race, dtype: int64

# %%
killings.race.value_counts().plot(kind="pie", title="Killings by Race", colormap = "Spectral")

# %% [markdown]
# ### 10. Display a histogram of ages of all killings

# %%
killings.age.hist(figsize=(20,12),bins = 10, color = "purple")

# %% [markdown]
# ### 11. Show histogram of ages for each race

# %%
#agerange = killings.age.value_counts()
#agerange

killings.age.hist(by=killings.race, figsize = (20,12), bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e415d30>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f465358>]], dtype=object)

# %% [markdown]
# ### 12. What is the average age of death by race?

# %%
#movies.groupby("director_name")["gross"].mean().sort_values(ascending=False).head()

killings.groupby("race")["age"].mean().sort_values()
# Out:
# race
# Native American           27.750000
# Hispanic/Latino           31.716418
# Black                     34.044444
# White                     40.466102
# Asian/Pacific Islander    40.800000
# Unknown                   43.533333
# Name: age, dtype: float64

# %% [markdown]
# ### 13. Show a bar chart with counts of deaths every month

# %%
#killings.plot()

# %%
killings.month.value_counts().plot(kind="bar")

# %% [markdown]
# ## Section 2: College Majors

# %%
majors = pd.read_csv('../data/college-majors.csv', index_col=[0])
majors.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %% [markdown]
# ### 1. Delete the columns (employed_full_time_year_round, major_code)

# %%
majors.columns = majors.columns.str.lower()
majors.head()
# Out:
#    major_code                                  major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     major_category   total  employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    employed_full_time_year_round  unemployed  unemployment_rate  median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %%
#yourdf.drop(['columnheading1', 'columnheading2'], axis=1, inplace=True)

majors.drop(['employed_full_time_year_round','major_code'], axis =1, inplace=True)
majors.head()
# Out:
#                                    major                   major_category  \
# 0                    GENERAL AGRICULTURE  Agriculture & Natural Resources
# 1  AGRICULTURE PRODUCTION AND MANAGEMENT  Agriculture & Natural Resources
# 2                 AGRICULTURAL ECONOMICS  Agriculture & Natural Resources
# 3                        ANIMAL SCIENCES  Agriculture & Natural Resources
# 4                           FOOD SCIENCE  Agriculture & Natural Resources
#
#     total  employed  unemployed  unemployment_rate  median  p25th    p75th
# 0  128148     90245        2423           0.026147   50000  34000  80000.0
# 1   95326     76865        2266           0.028636   54000  36000  80000.0
# 2   33955     26321         821           0.030248   63000  40000  98000.0
# 3  103549     81177        3619           0.042679   46000  30000  72000.0
# 4   24280     17281         894           0.049188   62000  38500  90000.0

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
majors.isnull().sum()
# Out:
# major                0
# major_category       0
# total                0
# employed             0
# unemployed           0
# unemployment_rate    0
# median               0
# p25th                0
# p75th                0
# dtype: int64

# %%
majors.shape
# Out:
# (173, 9)

# %%
majors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 172
# Data columns (total 9 columns):
# major                173 non-null object
# major_category       173 non-null object
# total                173 non-null int64
# employed             173 non-null int64
# unemployed           173 non-null int64
# unemployment_rate    173 non-null float64
# median               173 non-null int64
# p25th                173 non-null int64
# p75th                173 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 13.5+ KB

# %% [markdown]
# ### 3. What are the top 10 highest paying majors?

# %%
highsal = majors.sort_values(by = 'median',ascending=False).head(10)
highsal
# Out:
#                                                  major  \
# 59                               PETROLEUM ENGINEERING
# 154  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 57           NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 55                           METALLURGICAL ENGINEERING
# 58                                 NUCLEAR ENGINEERING
# 56                      MINING AND MINERAL ENGINEERING
# 97                    MATHEMATICS AND COMPUTER SCIENCE
# 48                              ELECTRICAL ENGINEERING
# 45                                CHEMICAL ENGINEERING
# 51              GEOLOGICAL AND GEOPHYSICAL ENGINEERING
#
#               major_category   total  employed  unemployed  unemployment_rate  \
# 59               Engineering   19631     14002         617           0.042205
# 154                   Health  180084    124058        4414           0.034358
# 57               Engineering   16094     10690         449           0.040309
# ...

# %% [markdown]
# ### 4. Plot the data from the last question in a bar chart, include proper title, and labels

# %%
#df1 = df[['a','b']]

sal = majors[["major", "median"]]
salhigh =sal.sort_values(by="median",ascending=False).head(10)

# %%
salp = salhigh.plot(x="major", y="median",kind="barh", figsize=(15,5), title = "Highest Paying Majors", color="red",legend=False)
salp.set_xlabel("Median Salary")
salp.set_ylabel("Major")
# Out:
# Text(0,0.5,'Major')

# %% [markdown]
# ### 5. What is the average median salary for each major category?

# %%
cols = ["median"]
catavg = majors.groupby("major_category")[cols].mean()
catavg
# Out:
#                                            median
# major_category
# Agriculture & Natural Resources      55000.000000
# Arts                                 43525.000000
# Biology & Life Science               50821.428571
# Business                             60615.384615
# Communications & Journalism          49500.000000
# Computers & Mathematics              66272.727273
# Education                            43831.250000
# Engineering                          77758.620690
# Health                               56458.333333
# Humanities & Liberal Arts            46080.000000
# Industrial Arts & Consumer Services  52642.857143
# Interdisciplinary                    43000.000000
# Law & Public Policy                  52800.000000
# Physical Sciences                    62400.000000
# Psychology & Social Work             44555.555556
# Social Science                       53222.222222

# %% [markdown]
# ### 6. Visualize only the top 5 paying major categories

# %%
highmaj = catavg.sort_values(by="median", ascending=False).head(5).plot(kind = "barh", figsize = (16,8), title = "Highest Paying Major Categories",legend=False)
highmaj.set_xlabel("Median Salary")
highmaj.set_ylabel("Major Category")
# Out:
# Text(0,0.5,'Major Category')

# %% [markdown]
# ### 7. Plot a histogram of the distribution of median salaries

# %%
majors["median"].hist(figsize=(15,5), bins =12)

# %% [markdown]
# ### 8. Plot a histogram of the distribution of median salaries by major category

# %%
majors["median"].hist(by=majors.major_category, figsize=(20,20), bins =10, color="pink")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a20113c88>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a205aa780>]], dtype=object)

# %% [markdown]
# ### 9. What are the top 10 most UNemployed majors?

# %%
majors.head()
# Out:
#                                    major                   major_category  \
# 0                    GENERAL AGRICULTURE  Agriculture & Natural Resources
# 1  AGRICULTURE PRODUCTION AND MANAGEMENT  Agriculture & Natural Resources
# 2                 AGRICULTURAL ECONOMICS  Agriculture & Natural Resources
# 3                        ANIMAL SCIENCES  Agriculture & Natural Resources
# 4                           FOOD SCIENCE  Agriculture & Natural Resources
#
#     total  employed  unemployed  unemployment_rate  median  p25th    p75th
# 0  128148     90245        2423           0.026147   50000  34000  80000.0
# 1   95326     76865        2266           0.028636   54000  36000  80000.0
# 2   33955     26321         821           0.030248   63000  40000  98000.0
# 3  103549     81177        3619           0.042679   46000  30000  72000.0
# 4   24280     17281         894           0.049188   62000  38500  90000.0

# %%
unmajor = majors[["major","unemployment_rate"]].sort_values(by="unemployment_rate",ascending=False)

unmajor.head(10)
# Out:
#                                         major  unemployment_rate
# 146                   MISCELLANEOUS FINE ARTS           0.156147
# 116                       CLINICAL PSYCHOLOGY           0.102712
# 93                      MILITARY TECHNOLOGIES           0.101796
# 27                  SCHOOL STUDENT COUNSELING           0.101746
# 77                            LIBRARY SCIENCE           0.094843
# 141                VISUAL AND PERFORMING ARTS           0.094658
# 19   COMPUTER PROGRAMMING AND DATA PROCESSING           0.090264
# 119                         SOCIAL PSYCHOLOGY           0.087336
# 104                ASTRONOMY AND ASTROPHYSICS           0.086022
# 11                               ARCHITECTURE           0.085991

# %% [markdown]
# ### 10. What are the top 10 most UNemployed majors CATEGORIES? Use the mean for each category

# %%
uncat = majors.groupby("major_category")["unemployment_rate"].mean().sort_values(ascending=False)
uncat.head(10)
# Out:
# major_category
# Arts                                   0.087601
# Psychology & Social Work               0.077867
# Interdisciplinary                      0.077269
# Humanities & Liberal Arts              0.069429
# Communications & Journalism            0.069125
# Law & Public Policy                    0.067854
# Social Science                         0.065686
# Computers & Mathematics                0.059437
# Industrial Arts & Consumer Services    0.058546
# Physical Sciences                      0.054541
# Name: unemployment_rate, dtype: float64

# %% [markdown]
# ## Section 3: FIFA Soccer Game data

# %%
fifa = pd.read_csv('../data/fifa_data.csv')
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# ...

# %% [markdown]
# ### 1. Clean up the dataset.
#
#     - Lowercase the column names
#     - Set the "name" column as the index
#     - Drop the following columns "national_position", "national_kit", "club_kit", "club_joining", and "contract_expiry"
#     - Get rid of all players who are goalkeepers and drop every column that starts with GK
#     - Drop every player whose rating is less than 70
#     - Convert the "height" and "weight" columns to float types
#     - Check to see if there any nulls, if so drop them from the dataset

# %%
fifa.columns = fifa.columns.str.lower()
fifa.set_index("name", inplace=True)
fifa.head()
# Out:
#                   nationality national_position  national_kit          club  \
# name
# Cristiano Ronaldo    Portugal                LS           7.0   Real Madrid
# Lionel Messi        Argentina                RW          10.0  FC Barcelona
# Neymar                 Brazil                LW          10.0  FC Barcelona
# Luis Suárez           Uruguay                LS           9.0  FC Barcelona
# Manuel Neuer          Germany                GK           1.0     FC Bayern
#
#                   club_position  club_kit club_joining  contract_expiry  \
# name
# Cristiano Ronaldo            LW       7.0   07/01/2009           2021.0
# Lionel Messi                 RW      10.0   07/01/2004           2018.0
# Neymar                       LW      11.0   07/01/2013           2021.0
# Luis Suárez                  ST       9.0   07/11/2014           2021.0
# Manuel Neuer                 GK       1.0   07/01/2011           2021.0
#
# ...

# %%
fifa.drop(['national_position', 'national_kit', 'club_kit', 'club_joining', 'contract_expiry'], axis=1,inplace=True)
fifa.head()
# Out:
#                   nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo    Portugal   Real Madrid            LW      94  185 cm
# Lionel Messi        Argentina  FC Barcelona            RW      93  170 cm
# Neymar                 Brazil  FC Barcelona            LW      92  174 cm
# Luis Suárez           Uruguay  FC Barcelona            ST      92  182 cm
# Manuel Neuer          Germany     FC Bayern            GK      92  193 cm
#
#                   weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo  80 kg          Right  02/05/1985   32              LW/ST
# Lionel Messi       72 kg           Left  06/24/1987   29                 RW
# Neymar             68 kg          Right  02/05/1992   25                 LW
# Luis Suárez        85 kg          Right  01/24/1987   30                 ST
# Manuel Neuer       92 kg          Right  03/27/1986   31                 GK
#
# ...

# %%
fifa = fifa[fifa.club_position != "GK"]
fifa.head()
# Out:
#                    nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo     Portugal   Real Madrid            LW      94  185 cm
# Lionel Messi         Argentina  FC Barcelona            RW      93  170 cm
# Neymar                  Brazil  FC Barcelona            LW      92  174 cm
# Luis Suárez            Uruguay  FC Barcelona            ST      92  182 cm
# Robert Lewandowski      Poland     FC Bayern            ST      90  185 cm
#
#                    weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo   80 kg          Right  02/05/1985   32              LW/ST
# Lionel Messi        72 kg           Left  06/24/1987   29                 RW
# Neymar              68 kg          Right  02/05/1992   25                 LW
# Luis Suárez         85 kg          Right  01/24/1987   30                 ST
# Robert Lewandowski  79 kg          Right  08/21/1988   28                 ST
#
# ...

# %%
fifa.drop(["gk_positioning", "gk_diving", "gk_kicking", "gk_handling", "gk_reflexes"], axis = 1, inplace=True)
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16956 entries, Cristiano Ronaldo to Barry Richardson
# Data columns (total 42 columns):
# nationality           16956 non-null object
# club                  16956 non-null object
# club_position         16955 non-null object
# rating                16956 non-null int64
# height                16956 non-null object
# weight                16956 non-null object
# preffered_foot        16956 non-null object
# birth_date            16956 non-null object
# age                   16956 non-null int64
# preffered_position    16956 non-null object
# work_rate             16956 non-null object
# weak_foot             16956 non-null int64
# skill_moves           16956 non-null int64
# ball_control          16956 non-null int64
# dribbling             16956 non-null int64
# marking               16956 non-null int64
# sliding_tackle        16956 non-null int64
# standing_tackle       16956 non-null int64
# ...

# %%
fifa = fifa[fifa.club_position != "GK"]

fifa = fifa[fifa.rating >= 70]
fifa.head()
# Out:
#                    nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo     Portugal   Real Madrid            LW      94  185 cm
# Lionel Messi         Argentina  FC Barcelona            RW      93  170 cm
# Neymar                  Brazil  FC Barcelona            LW      92  174 cm
# Luis Suárez            Uruguay  FC Barcelona            ST      92  182 cm
# Robert Lewandowski      Poland     FC Bayern            ST      90  185 cm
#
#                    weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo   80 kg          Right  02/05/1985   32              LW/ST
# Lionel Messi        72 kg           Left  06/24/1987   29                 RW
# Neymar              68 kg          Right  02/05/1992   25                 LW
# Luis Suárez         85 kg          Right  01/24/1987   30                 ST
# Robert Lewandowski  79 kg          Right  08/21/1988   28                 ST
#
# ...

# %%
fifa.sort_values(by="rating").head()
# Out:
#                         nationality           club club_position  rating  \
# name
# Anatole Ngamukol  Equatorial Guinea    Red Star FC            RS      70
# Brandon Thomas                Spain   RCD Mallorca            ST      70
# Issiaga Sylla                Guinea    Toulouse FC           Sub      70
# Jonas Meffert               Germany  Karlsruher SC           LDM      70
# Andrés Rentería            Colombia      Querétaro           Sub      70
#
#                   height weight preffered_foot  birth_date  age  \
# name
# Anatole Ngamukol  178 cm  70 kg          Right  01/15/1988   29
# Brandon Thomas    173 cm  65 kg          Right  02/04/1995   22
# Issiaga Sylla     180 cm  75 kg           Left  01/01/1994   23
# Jonas Meffert     186 cm  77 kg          Right  09/04/1994   22
# Andrés Rentería   179 cm  81 kg          Right  03/06/1993   24
#
#                  preffered_position   ...    agility  jumping  heading  \
# name                                  ...
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5232 entries, Cristiano Ronaldo to Anatole Ngamukol
# Data columns (total 42 columns):
# nationality           5232 non-null object
# club                  5232 non-null object
# club_position         5231 non-null object
# rating                5232 non-null int64
# height                5232 non-null object
# weight                5232 non-null object
# preffered_foot        5232 non-null object
# birth_date            5232 non-null object
# age                   5232 non-null int64
# preffered_position    5232 non-null object
# work_rate             5232 non-null object
# weak_foot             5232 non-null int64
# skill_moves           5232 non-null int64
# ball_control          5232 non-null int64
# dribbling             5232 non-null int64
# marking               5232 non-null int64
# sliding_tackle        5232 non-null int64
# standing_tackle       5232 non-null int64
# aggression            5232 non-null int64
# ...

# %%
fifa.height = fifa.height.str.replace("cm", "")
fifa.weight = fifa.weight.str.replace("kg", "")
fifa.height = fifa.height.astype('float64')
fifa.weight = fifa.weight.astype('float64')
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5232 entries, Cristiano Ronaldo to Anatole Ngamukol
# Data columns (total 42 columns):
# nationality           5232 non-null object
# club                  5232 non-null object
# club_position         5231 non-null object
# rating                5232 non-null int64
# height                5232 non-null float64
# weight                5232 non-null float64
# preffered_foot        5232 non-null object
# birth_date            5232 non-null object
# age                   5232 non-null int64
# preffered_position    5232 non-null object
# work_rate             5232 non-null object
# weak_foot             5232 non-null int64
# skill_moves           5232 non-null int64
# ball_control          5232 non-null int64
# dribbling             5232 non-null int64
# marking               5232 non-null int64
# sliding_tackle        5232 non-null int64
# standing_tackle       5232 non-null int64
# aggression            5232 non-null int64
# ...

# %%
fifa.isnull().sum()
# Out:
# nationality           0
# club                  0
# club_position         1
# rating                0
# height                0
# weight                0
# preffered_foot        0
# birth_date            0
# age                   0
# preffered_position    0
# work_rate             0
# weak_foot             0
# skill_moves           0
# ball_control          0
# dribbling             0
# marking               0
# sliding_tackle        0
# standing_tackle       0
# aggression            0
# reactions             0
# attacking_position    0
# interceptions         0
# vision                0
# composure             0
# crossing              0
# short_pass            0
# long_pass             0
# acceleration          0
# speed                 0
# stamina               0
# strength              0
# balance               0
# agility               0
# jumping               0
# heading               0
# shot_power            0
# finishing             0
# long_shots            0
# ...

# %%
fifa.dropna(axis=0, inplace=True)
fifa.isnull().sum()
# Out:
# nationality           0
# club                  0
# club_position         0
# rating                0
# height                0
# weight                0
# preffered_foot        0
# birth_date            0
# age                   0
# preffered_position    0
# work_rate             0
# weak_foot             0
# skill_moves           0
# ball_control          0
# dribbling             0
# marking               0
# sliding_tackle        0
# standing_tackle       0
# aggression            0
# reactions             0
# attacking_position    0
# interceptions         0
# vision                0
# composure             0
# crossing              0
# short_pass            0
# long_pass             0
# acceleration          0
# speed                 0
# stamina               0
# strength              0
# balance               0
# agility               0
# jumping               0
# heading               0
# shot_power            0
# finishing             0
# long_shots            0
# ...

# %% [markdown]
# ### 2.  Who are the top five players of the following attributes: speed, marking, and finishing

# %%
a = fifa.speed.sort_values(ascending=False).head()
b = fifa.marking.sort_values(ascending=False).head()
c = fifa.finishing.sort_values(ascending=False).head()

a
# Out:
# name
# Jonathan Biabiany            96
# Pierre-Emerick Aubameyang    96
# Gareth Bale                  95
# Ernest Asante                95
# Williams                     95
# Name: speed, dtype: int64

# %%
b
# Out:
# name
# Giorgio Chiellini    92
# Thiago Silva         90
# Jérôme Boateng       90
# Andrea Barzagli      90
# Miranda              89
# Name: marking, dtype: int64

# %%
c
# Out:
# name
# Lionel Messi          95
# Luis Suárez           94
# Cristiano Ronaldo     93
# Gonzalo Higuaín       92
# Robert Lewandowski    91
# Name: finishing, dtype: int64

# %% [markdown]
# ### 3. Who is the tallest French lefted foot player?

# %%
nat = fifa[(fifa.nationality == "France") & (fifa.preffered_foot == "Left")]
nat.sort_values(by="height", ascending=False).head(1)
# Out:
#               nationality        club club_position  rating  height  weight  \
# name
# Romain Thomas      France  Angers SCO           LCB      78   193.0    84.0
#
#               preffered_foot  birth_date  age preffered_position   ...     \
# name                                                               ...
# Romain Thomas           Left  06/12/1988   28                 CB   ...
#
#               agility  jumping  heading  shot_power  finishing  long_shots  \
# name
# Romain Thomas      54       68       79          60         19          24
#
#                curve  freekick_accuracy  penalties  volleys
# name
# Romain Thomas     39                 34         52       18
#
# [1 rows x 42 columns]

# %% [markdown]
# ### 4. Show a pandas series of every attribute's correlation with the rating attribute

# %%
ratcor = fifa.corr()['rating']

ratcor
# Out:
# rating                1.000000
# height                0.031355
# weight                0.037766
# age                   0.043735
# weak_foot             0.128486
# skill_moves           0.197929
# ball_control          0.324058
# dribbling             0.247239
# marking               0.067274
# sliding_tackle        0.091544
# standing_tackle       0.107487
# aggression            0.156163
# reactions             0.690226
# attacking_position    0.220396
# interceptions         0.126365
# vision                0.306819
# composure             0.436876
# crossing              0.209043
# short_pass            0.367006
# long_pass             0.307635
# acceleration          0.128840
# speed                 0.130594
# stamina               0.175219
# strength              0.105597
# balance               0.081555
# agility               0.145819
# jumping               0.107216
# heading               0.173646
# shot_power            0.248798
# finishing             0.213504
# ...

# %% [markdown]
# ### 5. Make a heatmap of the dataset's correlation table

# %%
plt.figure(figsize = (20,12))
sns.heatmap(fifa.corr())

# %% [markdown]
# ### 6. Return a dataframe with only players from the following clubs. Call the dataframe fifa2. From now on we'll be using fifa2

# %%
clubs_list = ['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
       'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
              'Bor. Dortmund', 'Liverpool', 'Roma']

# %%
fifa2 = fifa[fifa.club.isin(clubs_list)]
fifa2.head()
# Out:
#                    nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo     Portugal   Real Madrid            LW      94   185.0
# Lionel Messi         Argentina  FC Barcelona            RW      93   170.0
# Neymar                  Brazil  FC Barcelona            LW      92   174.0
# Luis Suárez            Uruguay  FC Barcelona            ST      92   182.0
# Robert Lewandowski      Poland     FC Bayern            ST      90   185.0
#
#                     weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo     80.0          Right  02/05/1985   32              LW/ST
# Lionel Messi          72.0           Left  06/24/1987   29                 RW
# Neymar                68.0          Right  02/05/1992   25                 LW
# Luis Suárez           85.0          Right  01/24/1987   30                 ST
# Robert Lewandowski    79.0          Right  08/21/1988   28                 ST
#
# ...

# %% [markdown]
# ### 7. Make a bar plot of the average long_shots, curve, and dribbling attributes of the clubs in the data

# %%
cols = ["long_shots", "curve", "dribbling"]

fifa2.groupby("club")[cols].mean().plot(kind = "bar", figsize = (20,8), title = "Skills by Club", colormap="Set2")

# %% [markdown]
# ### 8. Make a scatter plot of short_pass vs marking and use the preffered_foot column to color-encode the dots.

# %%
fifa2.head(20)
# Out:
#                    nationality             club club_position  rating  height  \
# name
# Cristiano Ronaldo     Portugal      Real Madrid            LW      94   185.0
# Lionel Messi         Argentina     FC Barcelona            RW      93   170.0
# Neymar                  Brazil     FC Barcelona            LW      92   174.0
# Luis Suárez            Uruguay     FC Barcelona            ST      92   182.0
# Robert Lewandowski      Poland        FC Bayern            ST      90   185.0
# Gareth Bale              Wales      Real Madrid            RW      90   183.0
# Zlatan Ibrahimović      Sweden   Manchester Utd            ST      90   195.0
# Jérôme Boateng         Germany        FC Bayern           Sub      89   192.0
# Eden Hazard            Belgium          Chelsea            LW      89   173.0
# Luka Modrić            Croatia      Real Madrid           RCM      89   174.0
# Mesut Özil             Germany          Arsenal           CAM      89   180.0
# ...

# %%
color_dict = {"Left":0, "Right":1}
fifa2.preffered_foot = fifa2.preffered_foot.map(color_dict)
fifa2.preffered_foot = fifa2.preffered_foot.astype('int64')
fifa2.plot(x = "short_pass", y = "marking", kind = "scatter",  c= "preffered_foot",figsize =(10, 7),colormap="PiYG")
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
fifa2.head()
# Out:
#                    nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo     Portugal   Real Madrid            LW      94   185.0
# Lionel Messi         Argentina  FC Barcelona            RW      93   170.0
# Neymar                  Brazil  FC Barcelona            LW      92   174.0
# Luis Suárez            Uruguay  FC Barcelona            ST      92   182.0
# Robert Lewandowski      Poland     FC Bayern            ST      90   185.0
#
#                     weight  preffered_foot  birth_date  age  \
# name
# Cristiano Ronaldo     80.0               1  02/05/1985   32
# Lionel Messi          72.0               0  06/24/1987   29
# Neymar                68.0               1  02/05/1992   25
# Luis Suárez           85.0               1  01/24/1987   30
# Robert Lewandowski    79.0               1  08/21/1988   28
#
#                    preffered_position   ...    agility  jumping  heading  \
# name                                    ...
# ...

# %% [markdown]
# ### 9. Make a grouped boxplots using club_position as the x axis for the following attributes: dribbling, balance, and sliding_tackle

# %%
fifa2.boxplot(column = "dribbling", by = "club_position",figsize=(20,8))
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# Which position is better at dribbling? ST or RCM? Why?

# %%
#ST is better at dribbling. ST has a greater median score than RCM, 
#and the lower quartile for ST is greater than the lower quartile for RCM.

# %%
#Balance boxplot
fifa2.boxplot(column = "balance", by = "club_position",figsize=(20,8))
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# Which position is better at balance? LM or LDM? Why?

# %%
#LM is better at balance. LM has a greater median score than LDM,
#and upper quartile for LM is greater than the upper quartile for LDM.

# %%
#sliding_tackle boxplot
fifa2.boxplot(column = "sliding_tackle", by = "club_position",figsize=(20,8))
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# What is the IQR for positions ST, RB, and RM?

# %%
cols = ["sliding_tackle"]

pos = ["ST", "RB", "RM"]
fifa2[fifa2.club_position.isin(pos)].groupby("club_position")[cols].describe()
# Out:
#               sliding_tackle                                                  \
#                        count       mean        std   min    25%   50%    75%
# club_position
# RB                       8.0  83.375000   5.902481  77.0  79.25  83.0  86.00
# RM                       6.0  57.666667  21.860162  26.0  42.50  64.0  74.25
# ST                      12.0  26.333333  10.662878  12.0  17.50  27.0  35.25
#
#
#                 max
# club_position
# RB             95.0
# RM             79.0
# ST             42.0
